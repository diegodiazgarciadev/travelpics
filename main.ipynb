# %%
import src.functions as f

# %%
coordinates = [3.630929643012765, 114.28075167898908] #some place in Asia
path_images = "./images"

# %%
f.create_map(coordinates, path_images)
# Out:
# ./images/20190115_163100(1).jpg  No Coordinates
# ./images/image_exif2.jpg  No Coordinates
# ./images/IMG_20180610_210127_161.jpg has no EXIF information
# ./images/P80813-173636-EFFECTS.jpg  No Coordinates
# ./images/P80815-112459.jpg  No Coordinates
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
